# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from  scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("Weather2.csv")
data
# Out:
#     year month  Tmean    RH  AirQuality
# 0   2011   Jan   21.5  65.3           2
# 1   2011   Feb   22.8  59.1           2
# 2   2011   Mar   25.9  49.7           1
# 3   2011   Apr   29.5  49.2           1
# 4   2011   May   35.1  37.5           1
# ..   ...   ...    ...   ...         ...
# 70  2016   Nov   25.9  56.7           2
# 71  2016   Dec   24.2  53.3           2
# 72  2011   Jan   21.0  58.9           2
# 73  2011   Feb   21.8  51.7           2
# 74  2011   Mar   24.5  42.6           3
#
# [75 rows x 5 columns]

# %%
sns.boxplot(x="AirQuality",y="Tmean",data=data,linewidth=1.5)
# Out:
# <AxesSubplot:xlabel='AirQuality', ylabel='Tmean'>

# %%
sns.pairplot(data)

# %%
 # lmplot():
sns.lmplot(x='RH',y='Tmean', data=data)

# %%
sns.lmplot(x='RH',y='Tmean', data=data,ci=95)

# %%
stats.linregress(data['RH'],data['Tmean'])
# Out:
# LinregressResult(slope=-0.21451246689808307, intercept=40.48883481252392, rvalue=-0.4076427282932335, pvalue=0.00028340156903695587, stderr=0.056240541081204944, intercept_stderr=3.1132388264358615)

# %%
#value of rvalue=-0.4076 means weak relationshep

# %%
#regiression line
slope, intercept, r_value, p_value, std_err = stats.linregress(data['year'],data['AirQuality'])
print("y="+str(np.round(slope,2))+"x+"+str(np.round(intercept,2)))
# Out:
# y=0.07x+-148.12

# %%
stats.pearsonr(data['RH'],data['Tmean'])
# Out:
# (-0.40764272829323356, 0.0002834015690369553)

# %%
sns.residplot(data=data,x='RH',y='Tmean')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#from above this show very good for predection.
